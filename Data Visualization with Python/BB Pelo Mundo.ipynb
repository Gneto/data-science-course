# %% [markdown]
# Négocios Internacionais do BB pelo Mundo

# %%
import pandas as pd
import folium

# %%
from google.colab import drive
drive.mount('/content/drive')

branchs = pd.read_excel('/content/drive/MyDrive/IBM Data Science/Data Visualization with Python/branchs_bb.xlsx')
branchs.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   BLK_CD BRN_CD                            BRN_NM  \
# 0     UE    VIE                Banco do Brasil AG
# 1    USA    GCM                   BB Grand Cayman
# 2    USA    BMB  Brazilian American Merchant Bank
# 3     UE    PAR                          BB Paris
# 4     UE    FFT    Banco do Brasil S.A. Frankfurt
#
#                              ADDR_TX                        ADDR_CMPL_TX  \
# 0              Praterstrasse 31/4.OG                         1020 Vienna
# 1  28 North Church Street, 2nd Floor  PO BOX 1360 KY1-1108, Grand Cayman
# 2  28 North Church Street, 2nd Floor  PO BOX 1360 KY1-1108, Grand Cayman
# 3                  29, Avenue Kleber   75116, 16o Arrondissement - Paris
# 4                     PO Box: 100362           Eschersheimer Landstr. 55
#
#                            CITY_NM BRN_LCY_CD        LAT        LON
# ...

# %%
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
point_branch = folium.FeatureGroup()

for lat, lng, in zip(branchs['LAT'], branchs['LON']):
  point_branch.add_child(
      folium.features.CircleMarker(
          [lat, lng],
          radius=5,
          color='yellow',
          fill=True,
          fill_color='blue',
          fill_opacity=0.6
      )
  )

latitudes = list(branchs['LAT'])
longitudes = list(branchs['LON'])
labels = list(branchs['BRN_NM'])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(world_map)  

world_map.add_child(point_branch)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
